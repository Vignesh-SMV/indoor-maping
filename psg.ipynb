# %%
import folium
from folium import plugins
import ipywidgets
import numpy as np
import pandas as pd
from vega_datasets import data as vds
import json
import os

# %% [markdown]
# <div style="background-color:#111111 ; padding: 20px;">
#
# <div style="text-align: center;">
#     <div style="display: inline-block; text-align: left;">
#         <img src="download.jpg" alt="Image Description" style="max-height: 100px; padding-right: 20px;">
#     </div>
#     <div style="display: inline-block; text-align: center;">
#         <h1 style=" padding: 10px;">
#             <span style=" color: #FF851B;">PSG College Of Arts And Science</span>
#         </h1>
#         <h2 style="padding: 10px; text-align: center;">
#             <span style=" color: #FF851B;">Indoor Navigation And Location</span>
#         </h2>
#     </div>
# </div>
# </div>

# %%
map_psg = folium.Map(location=[11.0327,77.0341], zoom_start=17)

# %%
df_suburbs=pd.read_excel("C:\\Users\\sharm\\OneDrive\\Desktop\\21BIT029_RaginiV_minorProject\\RaginiV_IndoorNavigator_Project\\PSG.xlsx",sheet_name="Sheet1")

# %%
df_suburbs_location=df_suburbs[['Latitude','Longitude']] 
suburbs_location_list=df_suburbs_location.values.tolist()
suburbs_location_list_size=len(suburbs_location_list)
# Out:
# 37

# %%
for point in range(suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point],popup=df_suburbs['Places'][point]).add_to(map_psg)

# %%
for point in range(0,suburbs_location_list_size):
    if df_suburbs['Symbol'][point] == 'Music':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='cadetblue', icon_color='white', icon='music', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'car':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='beige', icon_color='white', icon='parking', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'utensils':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='orange', icon_color='white', icon='utensils', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'bulidings':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='red', icon_color='white', icon='landmark', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'tree':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='green', icon_color='white', icon='tree', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'gopuram':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='purple', icon_color='white', icon='gopuram', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'rifle':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='darkpurple', icon_color='white', icon='person-rifle', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'dumbbell':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='lightgreen', icon_color='white', icon='dumbbell', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'hotel':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='lightred', icon_color='white', icon='hotel', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'Book':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='darkred', icon_color='white', icon='book', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'gate':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='darkpurple', icon_color='white', icon='dungeon', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'Meeting':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='darkgreen', icon_color='white', icon='handshake', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'restroom':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='black', icon_color='white', icon='restroom', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'sports':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='gray', icon_color='white', icon='volleyball', angle=0, prefix='fa')).add_to(map_psg)
    elif df_suburbs['Symbol'][point] == 'info':
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='blue', icon_color='white', icon='info', angle=0, prefix='fa')).add_to(map_psg)
    else:
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='darkblue', icon_color='white', icon='graduation-cap', angle=0, prefix='fa')).add_to(map_psg)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
class navigator:
    def __init__(self):
        self.geoResources = {}
        self.psg =(11.0327,77.0341)
        self.position = 'w'
        self.destination = 'Haus2'

        for root, dirs, files in os.walk("C:\\Users\\sharm\\OneDrive\\Desktop\\21BIT029_RaginiV_minorProject\\RaginiV_IndoorNavigator_Project\\GeoResources"):  
            for file in files:
                self.geoResources[file.split('.')[0]] = root+'/'+file

    def changeDestination(self,newDestination):
        self.destination = newDestination
        self.redrawMap()

    def changeStartPoint(self, newStartPoint):
        
        self.position = newStartPoint #does not work yet
        #print(f'Selected Start: {newStartPoint}; Selected Target: {self.destination}')
    
        

    def drawPathWay(self,map_psg):
      
      def switchPosition(coordinate):
        temp = coordinate[0]
        coordinate[0] = coordinate[1]
        coordinate[1] = temp
        return coordinate

      searchString = self.position + self.destination.split('Haus')[1]
      with open(self.geoResources[searchString]) as f:
           testWay = json.load(f)

      for feature in testWay['features']:
        path = feature['geometry']['coordinates']

      finalPath = list(map(switchPosition,path))
      folium.plugins.AntPath(finalPath).add_to(map_psg)


    def redrawMap(self):
        #print(f'position {self.position}, destination {self.destination}')
        PSGmap = folium.Map(location = self.psg,zoom_start = 17)
        self.drawPathWay(PSGmap)
        for point in range(0,suburbs_location_list_size):
            if df_suburbs['Symbol'][point] == 'Music':
                folium.Marker(suburbs_location_list[point],popup=df_suburbs['Places'][point],
                              icon=folium.Icon(color='cadetblue', icon_color='white', icon='music', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'car':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='beige', icon_color='white', icon='parking', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'utensils':
                folium.Marker(suburbs_location_list[point],popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='orange', icon_color='white', icon='utensils', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'bulidings':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='red', icon_color='white', icon='landmark', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'tree':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='green', icon_color='white', icon='tree', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'gopuram':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='purple', icon_color='white', icon='gopuram', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'rifle':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='darkpurple', icon_color='white', icon='person-rifle', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'dumbbell':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='lightgreen', icon_color='white', icon='dumbbell', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'hotel':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='lightred', icon_color='white', icon='hotel', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'Book':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='darkred', icon_color='white', icon='book', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'gate':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='darkpurple', icon_color='white', icon='dungeon', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'Meeting':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='darkgreen', icon_color='white', icon='handshake', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'restroom':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='black', icon_color='white', icon='restroom', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'sports':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='gray', icon_color='white', icon='volleyball', angle=0, prefix='fa')).add_to(PSGmap)
            elif df_suburbs['Symbol'][point] == 'info':
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='blue', icon_color='white', icon='info', angle=0, prefix='fa')).add_to(PSGmap)
            else:
                folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Places'][point], 
                      icon=folium.Icon(color='darkblue', icon_color='white', icon='graduation-cap', angle=0, prefix='fa')).add_to(PSGmap)
        display(PSGmap)

# %%
myNavigator = navigator()

# %%
def displayWay(whereTo):
     myNavigator.changeDestination(whereTo)

# %%
def changePosition(whereFrom):
    myNavigator.changeStartPoint(whereFrom)

# %%
# Destination Selector
selectHouse_widget=ipywidgets.Select(
    
options=['A-Block',
    'Bike Parking',
    'Braham Hall',
    'D-Block',
    'Gym',
    'E-Block',
    'Back-Gate',
    'Food Processing centre',
    'F-Block',
    'Indoor Stadium',
    'B-Block',
    'Stone Bench',
    'Ncc Camp',
    'Temple 2',
    'Poyhigai Hall',
    'Seed Office',
    'Prinicipal Office',
    'Rest Room',
    'Sf Office',
    'C-Block',
    'Bharathi Hostel',
    'Volleyball court',
    'Yamuna Hostel',
    'Megala Hostel',
    'Kurinji Hostel',
    'Marutham Hostel',
    'Library',
    'GRD auditorium',
    'Back Canteen',
    'G-Block',
    'Q-Block',
    'Steel Bench',
    'Daffoidiel',
    'Bharathi Hostel'
    'Temple 1',
    'Ganga Hostel',
    'Car Parking',
    'Food Court'],
    value='A-Block',
    description='Destination',
    disabled=False)

# widget function
def selectHouse(way):
    if way == 'A-Block' :
        displayWay('Haus1' ) 
    if way == 'Bike Parking':
        displayWay('Haus10')
    if way == 'Braham Hall':
        displayWay('Haus11')
    if way == 'D-Block':
        displayWay('Haus12')
    if way == 'Gym':
        displayWay('Haus13')
    if way == 'E-Block':
        displayWay('Haus14')
    if way == 'Back-Gate':
        displayWay('Haus15')
    if way == 'Food Processing centre':
        displayWay('Haus16')
    if way == 'F-Block':
       displayWay('Haus17')
    if way == 'Indoor Stadium':
        displayWay('Haus19')
    if way == 'B-Block' :
        displayWay('Haus2' ) 
    if way == 'Stone Bench':
        displayWay('Haus20')
    if way == 'Ncc Camp':
        displayWay('Haus22')
    if way == 'Temple 2':
        displayWay('Haus24')
    if way == 'Pothigai Hall':
        displayWay('Haus25')
    if way == 'Seed Office':
        displayWay('Haus26')
    if way == 'Prinicipal Office':
        displayWay('Haus27')
    if way == 'Rest Room':
        displayWay('Haus28')
    if way == 'Sf Office':
        displayWay('Haus29')
    if way == 'C-Block' :
        displayWay('Haus3' ) 
    if way == 'Bharathi Hostel':
        displayWay('Haus30')
    if way == 'Volleyball court':
        displayWay('Haus31')
    if way == 'Yamuna Hostel':
        displayWay('Haus32')
    if way == 'Megala Hostel':
        displayWay('Haus33')
    if way == 'Kurinji Hostel':
        displayWay('Haus34')
    if way == 'Marutham Hostel':
        displayWay('Haus35')
    if way == 'GRD auditorium' :
        displayWay('Haus5' ) 
    if way == 'Back Canteen' :
        displayWay('Haus6' ) 
    if way == 'G-Block' :
        displayWay('Haus7' ) 
    if way == 'Q-Block' :
        displayWay('Haus8' ) 
    if way == 'Car Parking' :
        displayWay('Haus9' )
    if way ==('Daffoidiel'):
        displayWay('Haus18')
    if way ==('Temple 1'):
        displayWay('Haus23')
    if way ==('Steel Bench'):
        displayWay('Haus21')
    if way==('Ganga Hostel'):
        displayWay('Haus36')
    if way==('Food Court'):
        displayWay('Haus37')

# Position Selector
selectPosition_widget=ipywidgets.Select(
    options=['Back', 'Front', 'Food', 'C-Block'],
    value='Front',
    description='Source',
    disabled=False)

def selectPosition(position):
    if position == 'Back':
        changePosition('a')
    if position == 'Front':
        changePosition('w')
    if position == 'Food':
        changePosition('o')
    if position == 'C-Block':
        changePosition('c')
        
#Initialization   
ipywidgets.interact(selectPosition, position=selectPosition_widget)
ipywidgets.interact(selectHouse, way=selectHouse_widget)
# Out:
# interactive(children=(Select(description='Source', index=1, options=('Back', 'Front', 'Food', 'C-Block'), valu…
# interactive(children=(Select(description='Destination', options=('A-Block', 'Bike Parking', 'Braham Hall', 'D-…
# <function __main__.selectHouse(way)>
